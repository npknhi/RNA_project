# %% [markdown]
# # RNA Folding Pipeline Notebook
# This notebook runs the full pipeline: training, plotting, scoring.

# %%
import src.training as training
training.run_train()
# Out:
# Profiles saved to data\profiles

# %%
import src.plotting as plotting
plotting.make_plot()
# Out:
# Plots saved to data\plots

# %%
import src.scoring as scoring
scoring.run_score()
# Out:
#  - 4GXY.pdb: 9.8973
#  - 4R4V.pdb: 7.7549
#  - 5TPY.pdb: 1.9646
#  - 7BG9.pdb: -26.4003
#  - 7QR4.pdb: -1.8667
#  - PZ18_Chen_1.pdb: 12.4888
#  - PZ18_DasORIGINAL_1.pdb: 11.8213
#  - PZ18_Das_1.pdb: 13.0473
#  - PZ30_Bujnicki_1.pdb: -1.6485
#  - PZ30_Chen_1.pdb: -1.9765
#  - PZ30_Ding_1.pdb: 11.8480
#  - PZ35_Bujnicki_1.pdb: 2.0723
#  - PZ35_Chen_1.pdb: 1.3357
#  - PZ35_Dfold2_1.pdb: 29.1423
#  - PZ6_Bujnicki_1.pdb: 11.5414
#  - PZ6_Chen_1.pdb: 50.1572
#  - PZ6_Das_1.pdb: 73.4046
#  - PZ7_Adamiak_1.pdb: 76.1352
#  - PZ7_Bujnicki_1.pdb: 87.8131
#  - PZ7_Chen_1.pdb: 38.4915
# Scores saved to data\scores\scores.csv
