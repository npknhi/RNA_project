# %% [markdown]
# # RNA Folding Pipeline Notebook
# This notebook runs the full pipeline: training, plotting, scoring.

# %%
rna = '8DP3'

# %%
# !python src/training.py $rna
# Out:
# Processing native: data/pdbs\8DP3\native.pdb
# ✔ Training completed for 8DP3

# %%
# !python src/plotting.py $rna
# Out:
# Plotting profiles for RNA: 8DP3
# Input:  data/profiles\8DP3
# Output folder: plot\8DP3
# ✔ Saved: plot\8DP3\AA.png
# ✔ Saved: plot\8DP3\AU.png
# ✔ Saved: plot\8DP3\AC.png
# ✔ Saved: plot\8DP3\AG.png
# ✔ Saved: plot\8DP3\UU.png
# ✔ Saved: plot\8DP3\UC.png
# ✔ Saved: plot\8DP3\UG.png
# ✔ Saved: plot\8DP3\CC.png
# ✔ Saved: plot\8DP3\CG.png
# ✔ Saved: plot\8DP3\GG.png
# ✔ Combined figure saved: plot\8DP3\8DP3_combined.png

# %%
# !python src/evaluation.py $rna
# Out:
# === Evaluation Results for 8DP3 ===
# MODEL                SCORE
# --------------------------------
# 8DP3 - Copy (2).pdb  116.0722
# 8DP3 - Copy (3).pdb  116.0722
# 8DP3 - Copy.pdb      116.0722
#
# CSV saved to: data/results\8DP3.csv
