# %% [markdown]
# # RNA Folding Pipeline Notebook
# This notebook runs the full pipeline: training, plotting, scoring.

# %%
import src.training as training
training.run_train()
# Out:
# Profiles saved to data\profiles\8DP3

# %%
import src.plotting as plotting
plotting.make_plot()
# Out:
# Plots saved to data\plot\8DP3

# %%
import src.scoring as scoring
scoring.run_score()
# Out:
#  - 8DP3 - model 1.pdb: 33.2891
#  - 8DP3 - model 2.pdb: 33.2891
#  - 8DP3 - model 3.pdb: 33.2891
#  - native.pdb: 33.2891
# Scores saved to data\scores\8DP3\scores.csv
